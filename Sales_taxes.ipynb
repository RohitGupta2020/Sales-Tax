# %%
import math

class Programs:

    def __init__(self):  # class constructur (called at creation time)
        self.goods = "" 
        self.price = ""
        self.quantity = ""
    
    def x_round(self,sales_tax):
                    return math.ceil(sales_tax*0.05)/0.05
                


    def _ask(self):
        while 1: # infinite loop
            goods = input("goods: ")
            Price = float(input("Price: "))
            Quantity = int(input("Quantity: "))
            
            if (goods == "" )& (Price == "" )& (Quantity == ""):
                print( "Ops! Retry")
            else:
                print( "Good,Price,quantity", goods,Price,Quantity)
            break  # this will break the loop
    

        self.goods = goods 
        self.price = Price
        self.quantity = Quantity 
        print(self.process())
        
        # return goods,price,quantity
        
        ## calculation
    def process(self):
        if (self.goods != 'Books') and (self.goods != 'Food') and (self.goods != 'Medical_products'):
            
            print("inside")
            sales_tax = (10*self.price)/100
            _f=(5*self.price)/100
            r = round(self.price+sales_tax+_f,2)
            
            # def x_round(sales_tax):
            #     return math.ceil(sales_tax*0.05)/0.05
            # total = self.x_round(sales_tax)
            # total = self.price
            print(self.quantity,self.goods,r)
            res = [self.quantity,self.goods,r]
            return res
        else:
            print("esle")
            sales_tax='0'
            print(self.goods,self.quantity,self.price)  
            res = [self.goods,self.quantity, self.price]
            return res
        

            
            
            
prog = Programs()
prog._ask()
# Out:
# goods: Books
# Price: 14.99
# Quantity: 1
# Good,Price,quantity Books 14.99 1
# esle
# Books 1 14.99
# ['Books', 1, 14.99]

# %%
import math

class Programs:

    def __init__(self):  # class constructur (called at creation time)
        self.goods = "" 
        self.price = ""
        self.quantity = ""
    
    def x_round(self,sales_tax):
                    return math.ceil(sales_tax*0.05)/0.05
                


    def _ask(self):
        while 1: # infinite loop
            goods = input("goods: ")
            Price = float(input("Price: "))
            Quantity = int(input("Quantity: "))
            
            if (goods == "" )& (Price == "" )& (Quantity == ""):
                print( "Ops! Retry")
            else:
                print( "Good,Price,quantity", goods,Price,Quantity)
            break  # this will break the loop
    

        self.goods = goods 
        self.price = Price
        self.quantity = Quantity 
        print(self.process())
        
        # return goods,price,quantity
        
        ## calculation
    def process(self):
        if (self.goods != 'Books') and (self.goods != 'Food') and (self.goods != 'Medical_products'):
            
            print("inside")
            sales_tax = (10*self.price)/100
            _f=(5*self.price)/100
            r = round(self.price+sales_tax+_f,2)
            
            # def x_round(sales_tax):
            #     return math.ceil(sales_tax*0.05)/0.05
            # total = self.x_round(sales_tax)
            # total = self.price
            print(self.quantity,self.goods, r)
            res = [self.quantity,self.goods, r]
            return res
        else:
            print("esle")
            sales_tax='0'
            print(self.goods,sales_tax,total)  
            res = [self.goods,sales_tax,total]
            return res
        

            
            
            
prog = Programs()
prog._ask()
# Out:
# goods: Oil
# Price: 14.99
# Quantity: 1
# Good,Price,quantity Oil 14.99 1
# inside
# 1 Oil 17.24
# [1, 'Oil', 17.24]

# %%
import math

class Programs:

    def __init__(self):  # class constructur (called at creation time)
        self.goods = "" 
        self.price = ""
        self.quantity = ""
    
    def x_round(self,sales_tax):
                    return math.ceil(sales_tax*0.05)/0.05
                


    def _ask(self):
        while 1: # infinite loop
            goods = input("goods: ")
            Price = float(input("Price: "))
            Quantity = int(input("Quantity: "))
            
            if (goods == "" )& (Price == "" )& (Quantity == ""):
                print( "Ops! Retry")
            else:
                print( "Good,Price,quantity", goods,Price,Quantity)
            break  # this will break the loop
    

        self.goods = goods 
        self.price = Price
        self.quantity = Quantity 
        print(self.process())
        
        # return goods,price,quantity
        
        ## calculation
    def process(self):
        if (self.goods != 'Books') and (self.goods != 'Food') and (self.goods != 'Medical_products'):
            
            print("inside")
            sales_tax = (10*self.price)/100
            _f=(5*self.price)/100
            r = round(self.price+sales_tax+_f,2)
            
            # def x_round(sales_tax):
            #     return math.ceil(sales_tax*0.05)/0.05
            # total = self.x_round(sales_tax)
            # total = self.price
            print(self.quantity,self.goods,self.price,sales_tax,r)
            res = [self.quantity,self.goods,self.price,sales_tax,r]
            return res
        else:
            print("esle")
            sales_tax='0'
            print(self.goods,self.quantity,self.price)  
            res = [self.goods,self.quantity, self.price]
            return res
        

            
            
            
prog = Programs()
prog._ask()
# Out:
# goods: Choc
# Price: 0.85
# Quantity: 1
# Good,Price,quantity Choc 0.85 1
# inside
# 1 Choc 0.085 0.98
# [1, 'Choc', 0.085, 0.98]
